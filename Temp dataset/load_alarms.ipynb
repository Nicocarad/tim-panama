# %%
import pandas as pd

# %%
mob = pd.read_parquet("20230101_20240101_all_clusters__mob_presented_make_pred_or_outage_or_lp_alarms_duplicated_link_alarms_with_flag.parquet")

# %%
mob_tx = pd.read_parquet("20230101_20240101_all_clusters__tx_mob_presented_make_pred_or_outage_or_lp_alarms_duplicated_link_alarms_with_flag.parquet")

# %%
tx = pd.read_parquet("20230101_20240101_all_clusters__tx_presented_make_pred_or_outage_or_lp_alarms_duplicated_link_alarms_with_flag.parquet")

# %%
mob
# Out:
#                              alarm_id  cluster_id2  cluster_id3 link_cluster
# 0        EFM;63b214e0d7aa71000199440d            1            0          NaN
# 3        EFM;63b4b35cd7aa710001995bce            3            2          NaN
# 7        EFM;63b57b0a2aaf2c000125b623            5            4          NaN
# 8        EFM;63b57b6dd7aa710001996662            5            4          NaN
# 12       EFM;63bc2eaa2aaf2c000125f764            9            8          NaN
# ...                               ...          ...          ...          ...
# 2176037  EFM;6540320a7b35f200017ca98d       799173       777615          NaN
# 2176038  EFM;6540320a7b35f200017ca98e       799173       777615          NaN
# 2176039  EFM;6540320cdcfbc200013159a9       799173       777615          NaN
# 2176040  EFM;6540320b7b35f200017ca98f       799173       777615          NaN
# 2176041  EFM;6540320ddcfbc200013159aa       799173       777615          NaN
#
# [665199 rows x 4 columns]

# %%
tx
# Out:
#                                alarm_id  cluster_id2  cluster_id3 link_cluster
# 1                       COS1P;136962430            2            1          NaN
# 2                       COS1P;136962434            2            1          NaN
# 4                       COS1P;137017732            4            3          NaN
# 5                       COS1P;137017736            4            3          NaN
# 6                       COS1P;137017735            4            3          NaN
# ...                                 ...          ...          ...          ...
# 2176001  EFMTX;65287b216e6df100011f868b       799168        66990       second
# 2176002  EFMTX;65287b7a743340000184b9dd       799168        66990       second
# 2176003  EFMTX;65287c0c2ea48300018bc7ce       799168        66990       second
# 2176009  EFMTX;65343d2a8e52a80001335dda       799170       777612          NaN
# 2176042  EFMTX;656c3a5b06272100018edfe7       799174       777616          NaN
#
# ...

# %%
real_time = pd.read_parquet("20230101-20240101_real_time_clusters.parquet")

# %%
real_time
# Out:
#                            alarm_id network ne_type    first_occurrence  \
# 0      EFM;63af9dfe2aaf2c000125807a      an   lnbts 2022-12-31 03:27:10
# 1      EFM;63af9dfec623b40001a5c9cf      an   lnbts 2022-12-31 03:27:10
# 2                   COS1P;136902468     sdh    ad16 2022-12-31 22:19:34
# 3      EFM;63b0beaf2aaf2c0001258736      an   lebts 2022-12-31 23:58:55
# 4                   COS1P;136891403     sdh    oadm 2022-12-31 11:26:16
# ..                              ...     ...     ...                 ...
# 110    EFM;6591f199d4c961000177739d      an   lnbts 2023-12-31 23:56:25
# 111    EFM;6591f19aba09b0000160c08d      an   lnbts 2023-12-31 23:56:26
# 112  EFMTX;6591ef8b975f5100015a479b     sdh    None 2023-12-31 23:47:39
# 113  EFMTX;6591f085e294c600010bf21a     sdh    ad16 2023-12-31 23:51:49
# 114  EFMTX;6591ef19d7d6bc000194445c     sdh    prhu 2023-12-31 23:45:45
#
#              last_update                data                 ne_id geo_code  \
# ...

# %%
real_time_old = pd.read_parquet("20230101-20240101_real_time_clusters_old.parquet")

# %%
real_time_old
# Out:
#                           alarm_id network ne_type     first_occurrence  \
# 0     EFM;63af9dfe2aaf2c000125807a      an   lnbts  2022-12-31 03:27:10
# 1     EFM;63af9dfec623b40001a5c9cf      an   lnbts  2022-12-31 03:27:10
# 2                  COS1P;136902468     sdh    ad16  2022-12-31 22:19:34
# 3     EFM;63b0beaf2aaf2c0001258736      an   lebts  2022-12-31 23:58:55
# 4                  COS1P;136891403     sdh    oadm  2022-12-31 11:26:16
# ..                             ...     ...     ...                  ...
# 38  EFMTX;6591efb9d7d6bc00019444d8    adsl    adsl  2023-12-31 23:48:25
# 39  EFMTX;6591f046d8beb800016deaef     ptn    ptn3  2023-12-31 23:50:46
# 40    EFM;6591f199d4c961000177739d      an   lnbts  2023-12-31 23:56:25
# 41    EFM;6591f19aba09b0000160c08d      an   lnbts  2023-12-31 23:56:26
# 42  EFMTX;6591ef19d7d6bc000194445c     sdh    prhu  2023-12-31 23:45:45
#
#             last_update                 data             ne_id geo_code  \
# ...
