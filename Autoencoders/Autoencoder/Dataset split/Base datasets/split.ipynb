# %%
import pandas as pd  
from sklearn.model_selection import train_test_split
import numpy as np

# %%
CONCATENATION = "slogan"

# %% [markdown]
# ## Create Train, Val and Test parquet file from indexes

# %%
result_df_gt_2  = pd.read_parquet("result_df_gt_2_" + CONCATENATION +".parquet")

# %%
result_df_gt_2
# Out:
#                   apparato isolato  fermo parziale sito tec  nan  \
# cluster_id2
# 202301010000_101                 1                        0    0
# 202301010000_102                 1                        0    0
# 202301010000_121                 1                        0    0
# 202301010000_122                 1                        0    0
# 202301010000_126                 1                        0    0
# ...                            ...                      ...  ...
# 202312312352_14                  0                        0    0
# 202312312352_6                   0                        0    0
# 202312312354_2                   0                        0    0
# 202312312354_6                   0                        0    0
# 202312312354_8                   0                        0    0
#
#                   alimentazione  signal degraded  loss of frame lof  \
# cluster_id2
# 202301010000_101              0                0                  0
# 202301010000_102              0                0                  0
# 202301010000_121              1                0                  0
# 202301010000_122              0                0                  0
# 202301010000_126              0                0                  0
# ...                         ...              ...                ...
# 202312312352_14               0                0                  1
# 202312312352_6                0                0                  0
# 202312312354_2                0                0                  0
# 202312312354_6                0                0                  0
# 202312312354_8                0                0                  0
#
#                   guasto matrice  fermo parziale gsm  fermo totale gsm  \
# cluster_id2
# 202301010000_101               0                   0                 0
# 202301010000_102               0                   0                 0
# 202301010000_121               0                   0                 0
# 202301010000_122               0                   0                 0
# 202301010000_126               0                   0                 0
# ...                          ...                 ...               ...
# 202312312352_14                0                   0                 0
# 202312312352_6                 0                   1                 0
# 202312312354_2                 0                   0                 0
# 202312312354_6                 0                   0                 0
# 202312312354_8                 0                   0                 0
#
#                   fermo totale 5g  ...  cardinitcard initializing  \
# cluster_id2                        ...
# 202301010000_101                0  ...                          0
# 202301010000_102                0  ...                          0
# 202301010000_121                0  ...                          0
# 202301010000_122                0  ...                          0
# 202301010000_126                0  ...                          0
# ...                           ...  ...                        ...
# 202312312352_14                 0  ...                          0
# 202312312352_6                  0  ...                          0
# 202312312354_2                  0  ...                          0
# 202312312354_6                  0  ...                          0
# 202312312354_8                  0  ...                          0
#
#                   mpls tunnel rdi mpls tunnel rdi  \
# cluster_id2
# 202301010000_101                                0
# 202301010000_102                                0
# 202301010000_121                                0
# 202301010000_122                                0
# 202301010000_126                                0
# ...                                           ...
# 202312312352_14                                 0
# 202312312352_6                                  0
# 202312312354_2                                  0
# 202312312354_6                                  0
# 202312312354_8                                  0
#
#                   vc unequipped ho vc unequipped  guasto controllore  \
# cluster_id2
# 202301010000_101                               0                   0
# 202301010000_102                               0                   0
# 202301010000_121                               0                   0
# 202301010000_122                               0                   0
# 202301010000_126                               0                   0
# ...                                          ...                 ...
# 202312312352_14                                0                   0
# 202312312352_6                                 0                   0
# 202312312354_2                                 0                   0
# 202312312354_6                                 0                   0
# 202312312354_8                                 0                   0
#
#                   vlan megaco ko  serversignalfailure odu ssf  \
# cluster_id2
# 202301010000_101               0                            0
# 202301010000_102               0                            0
# 202301010000_121               0                            0
# 202301010000_122               0                            0
# 202301010000_126               0                            0
# ...                          ...                          ...
# 202312312352_14                0                            0
# 202312312352_6                 0                            0
# 202312312354_2                 0                            0
# 202312312354_6                 0                            0
# 202312312354_8                 0                            0
#
#                   unidentified specific problem non inviato da agent  \
# cluster_id2
# 202301010000_101                                                  0
# 202301010000_102                                                  0
# 202301010000_121                                                  0
# 202301010000_122                                                  0
# 202301010000_126                                                  0
# ...                                                             ...
# 202312312352_14                                                   0
# 202312312352_6                                                    0
# 202312312354_2                                                    0
# 202312312354_6                                                    0
# 202312312354_8                                                    0
#
#                   replaceablemodulemissing eqpt  grave disservizio onuc  \
# cluster_id2
# 202301010000_101                              0                       0
# 202301010000_102                              0                       0
# 202301010000_121                              0                       0
# 202301010000_122                              0                       0
# 202301010000_126                              0                       0
# ...                                         ...                     ...
# 202312312352_14                               0                       0
# 202312312352_6                                0                       0
# 202312312354_2                                0                       0
# 202312312354_6                                0                       0
# 202312312354_8                                0                       0
#
#                   crdpwroff card power off xexc xexc
# cluster_id2
# 202301010000_101                                   0
# 202301010000_102                                   0
# 202301010000_121                                   0
# 202301010000_122                                   0
# 202301010000_126                                   0
# ...                                              ...
# 202312312352_14                                    0
# 202312312352_6                                     0
# 202312312354_2                                     0
# 202312312354_6                                     0
# 202312312354_8                                     0
#
# [616261 rows x 116 columns]

# %%
indices = np.arange(len(result_df_gt_2 ))
train_indices, test_indices = train_test_split(indices, test_size=0.3, random_state=42)
val_indices, test_indices = train_test_split(test_indices, test_size=0.5, random_state=42)

# %%
pd.DataFrame(train_indices).to_csv("train_indexes_" + CONCATENATION +".csv", index=False)
pd.DataFrame(val_indices).to_csv("val_indexes_"+ CONCATENATION +".csv", index=False)
pd.DataFrame(test_indices).to_csv("test_indexes_"+ CONCATENATION +".csv", index=False)

# %%
train_indexes_df = pd.read_csv("train_indexes_"+ CONCATENATION +".csv")  
val_indexes_df = pd.read_csv("val_indexes_"+ CONCATENATION +".csv")
test_indexes_df = pd.read_csv("test_indexes_"+ CONCATENATION +".csv")

# %%
train_indexes = train_indexes_df.iloc[:, 0].values
val_indexes = val_indexes_df.iloc[:, 0].values
test_indexes = test_indexes_df.iloc[:, 0].values

# %%
result_df_gt_2 = result_df_gt_2.reset_index()

# %%
# Divide il DataFrame utilizzando gli indici
train_df = result_df_gt_2.loc[train_indexes]
val_df = result_df_gt_2.loc[val_indexes]
test_df = result_df_gt_2.loc[test_indexes]

# %%
train_df.to_parquet('train_df_' + CONCATENATION +'.parquet')
val_df.to_parquet('val_df_' + CONCATENATION + '.parquet')
test_df.to_parquet('test_df_' + CONCATENATION + '.parquet')

# %%
train_df = pd.read_parquet('train_df_' + CONCATENATION +'.parquet')
val_df = pd.read_parquet('val_df_' + CONCATENATION + '.parquet')
test_df = pd.read_parquet('test_df_' + CONCATENATION + '.parquet')

# %%
train_df = train_df.reset_index(drop=True).set_index('cluster_id2')
val_df = val_df.reset_index(drop=True).set_index('cluster_id2')
test_df = test_df.reset_index(drop=True).set_index('cluster_id2')

# %%
train_df.to_parquet('train_df_' + CONCATENATION +'.parquet')
val_df.to_parquet('val_df_' + CONCATENATION + '.parquet')
test_df.to_parquet('test_df_' + CONCATENATION + '.parquet')
