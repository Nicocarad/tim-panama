# %%
import pandas as pd  
from sklearn.model_selection import train_test_split
import numpy as np

# %% [markdown]
# ## Create Train, Val and Test parquet file from indexes

# %%
result_df_gt_2  = pd.read_parquet("result_df_gt_2_ne_type_link.parquet")

# %%
result_df_gt_2
# Out:
#                   ad16_apparato isolato_None  adm4_apparato isolato_None  \
# cluster_id2
# 202301010000_101                           1                           0
# 202301010000_102                           1                           1
# 202301010000_121                           1                           0
# 202301010000_122                           0                           0
# 202301010000_126                           1                           0
# ...                                      ...                         ...
# 202312312352_14                            0                           0
# 202312312352_6                             0                           0
# 202312312354_2                             0                           0
# 202312312354_6                             0                           0
# 202312312354_8                             0                           0
#
#                   lhbts_fermo parziale sito tec_None  ad16_nan_None  \
# ...

# %%
indices = np.arange(len(result_df_gt_2 ))
train_indices, test_indices = train_test_split(indices, test_size=0.3, random_state=42)
val_indices, test_indices = train_test_split(test_indices, test_size=0.5, random_state=42)

# %%
pd.DataFrame(train_indices).to_csv("train_indexes_ne_type_link.csv", index=False)
pd.DataFrame(val_indices).to_csv("val_indexes_ne_type_link.csv", index=False)
pd.DataFrame(test_indices).to_csv("test_indexes_ne_type_link.csv", index=False)

# %%
train_indexes_df = pd.read_csv('train_indexes_ne_type_link.csv')  
val_indexes_df = pd.read_csv('val_indexes_ne_type_link.csv')
test_indexes_df = pd.read_csv('test_indexes_ne_type_link.csv')

# %%
train_indexes = train_indexes_df.iloc[:, 0].values
val_indexes = val_indexes_df.iloc[:, 0].values
test_indexes = test_indexes_df.iloc[:, 0].values

# %%
result_df_gt_2 = result_df_gt_2.reset_index()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 result_df_gt_2 = result_df_gt_2.reset_index()
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\frame.py:6417, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6415     new_obj = self
#    6416 else:
# -> 6417     new_obj = self.copy(deep=None)
#    6418 if allow_duplicates is not lib.no_default:
#    6419     allow_duplicates = validate_bool_kwarg(allow_duplicates, "allow_duplicates")
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\generic.py:6811, in NDFrame.copy(self, deep)
#    6662 @final
#    6663 def copy(self, deep: bool_t | None = True) -> Self:
#    6664     """
#    6665     Make a copy of this object's indices and data.
#    6666
#    (...)
#    6809     dtype: int64
# ...

# %%
# Divide il DataFrame utilizzando gli indici
train_df = result_df_gt_2.loc[train_indexes]
val_df = result_df_gt_2.loc[val_indexes]
test_df = result_df_gt_2.loc[test_indexes]

# %%
train_df.to_parquet('train_df_ne_type_link.parquet')
val_df.to_parquet('val_df_ne_type_link.parquet')
test_df.to_parquet('test_df_ne_type_link.parquet')

# %%
train_df = pd.read_parquet('train_df_ne_type_link.parquet')
val_df = pd.read_parquet('val_df_ne_type_link.parquet')
test_df = pd.read_parquet('test_df_ne_type_link.parquet')

# %%
train_df = train_df.reset_index(drop=True).set_index('cluster_id2')
val_df = val_df.reset_index(drop=True).set_index('cluster_id2')
test_df = test_df.reset_index(drop=True).set_index('cluster_id2')

# %%
train_df.to_parquet('train_df_ne_type_link.parquet')
val_df.to_parquet('val_df_ne_type_link.parquet')
test_df.to_parquet('test_df_ne_type_link.parquet')
