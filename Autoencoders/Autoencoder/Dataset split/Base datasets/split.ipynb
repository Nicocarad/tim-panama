# %%
import pandas as pd  
from sklearn.model_selection import train_test_split
import numpy as np

# %% [markdown]
# ## Create Train, Val and Test parquet file from indexes

# %%
result_df_gt_2  = pd.read_parquet("result_df_gt_2_ne_type_link.parquet")

# %%
result_df_gt_2
# Out:
#                   ad16_apparato isolato_None  adm4_apparato isolato_None  \
# cluster_id2
# 202301010000_101                           1                           0
# 202301010000_102                           1                           1
# 202301010000_121                           1                           0
# 202301010000_122                           0                           0
# 202301010000_126                           1                           0
# ...                                      ...                         ...
# 202312312352_14                            0                           0
# 202312312352_6                             0                           0
# 202312312354_2                             0                           0
# 202312312354_6                             0                           0
# 202312312354_8                             0                           0
#
#                   lhbts_fermo parziale sito tec_None  ad16_nan_None  \
# cluster_id2
# 202301010000_101                                   0              0
# 202301010000_102                                   0              0
# 202301010000_121                                   0              0
# 202301010000_122                                   0              0
# 202301010000_126                                   0              0
# ...                                              ...            ...
# 202312312352_14                                    0              0
# 202312312352_6                                     0              0
# 202312312354_2                                     0              0
# 202312312354_6                                     0              0
# 202312312354_8                                     0              0
#
#                   ad64_nan_None  adm1_apparato isolato_None  \
# cluster_id2
# 202301010000_101              0                           1
# 202301010000_102              0                           0
# 202301010000_121              0                           0
# 202301010000_122              0                           0
# 202301010000_126              0                           0
# ...                         ...                         ...
# 202312312352_14               0                           0
# 202312312352_6                0                           0
# 202312312354_2                0                           0
# 202312312354_6                0                           0
# 202312312354_8                0                           0
#
#                   ad64_alimentazione_None  ad16_alimentazione_None  \
# cluster_id2
# 202301010000_101                        0                        0
# 202301010000_102                        0                        0
# 202301010000_121                        0                        1
# 202301010000_122                        0                        0
# 202301010000_126                        0                        0
# ...                                   ...                      ...
# 202312312352_14                         0                        0
# 202312312352_6                          0                        0
# 202312312354_2                          0                        0
# 202312312354_6                          0                        0
# 202312312354_8                          0                        0
#
#                   ad64_apparato isolato_None  adm1_alimentazione_None  ...  \
# cluster_id2                                                            ...
# 202301010000_101                           0                        0  ...
# 202301010000_102                           0                        0  ...
# 202301010000_121                           0                        0  ...
# 202301010000_122                           1                        0  ...
# 202301010000_126                           0                        0  ...
# ...                                      ...                      ...  ...
# 202312312352_14                            0                        0  ...
# 202312312352_6                             0                        0  ...
# 202312312354_2                             0                        0  ...
# 202312312354_6                             0                        0  ...
# 202312312354_8                             0                        0  ...
#
#                   rmx3_potenza ottica anomala_None  \
# cluster_id2
# 202301010000_101                                 0
# 202301010000_102                                 0
# 202301010000_121                                 0
# 202301010000_122                                 0
# 202301010000_126                                 0
# ...                                            ...
# 202312312352_14                                  0
# 202312312352_6                                   0
# 202312312354_2                                   0
# 202312312354_6                                   0
# 202312312354_8                                   0
#
#                   oadm_loss of signal los_eth  ad64_loss of frame_oph  \
# cluster_id2
# 202301010000_101                            0                       0
# 202301010000_102                            0                       0
# 202301010000_121                            0                       0
# 202301010000_122                            0                       0
# 202301010000_126                            0                       0
# ...                                       ...                     ...
# 202312312352_14                             0                       0
# 202312312352_6                              0                       0
# 202312312354_2                              0                       0
# 202312312354_6                              0                       0
# 202312312354_8                              0                       0
#
#                   None_problema laser tx_None  ptn2_signal degraded_None  \
# cluster_id2
# 202301010000_101                            0                          0
# 202301010000_102                            0                          0
# 202301010000_121                            0                          0
# 202301010000_122                            0                          0
# 202301010000_126                            0                          0
# ...                                       ...                        ...
# 202312312352_14                             0                          0
# 202312312352_6                              0                          0
# 202312312354_2                              0                          0
# 202312312354_6                              0                          0
# 202312312354_8                              0                          0
#
#                   rxm5_loss of signal los_gb100  adm1_loss of signal los_482  \
# cluster_id2
# 202301010000_101                              0                            0
# 202301010000_102                              0                            0
# 202301010000_121                              0                            0
# 202301010000_122                              0                            0
# 202301010000_126                              0                            0
# ...                                         ...                          ...
# 202312312352_14                               0                            0
# 202312312352_6                                0                            0
# 202312312354_2                                0                            0
# 202312312354_6                                0                            0
# 202312312354_8                                0                            0
#
#                   oadm1_apparato isolato_None  rmx5_loss of signal los_None  \
# cluster_id2
# 202301010000_101                            0                             0
# 202301010000_102                            0                             0
# 202301010000_121                            0                             0
# 202301010000_122                            0                             0
# 202301010000_126                            0                             0
# ...                                       ...                           ...
# 202312312352_14                             0                             0
# 202312312352_6                              0                             0
# 202312312354_2                              0                             0
# 202312312354_6                              0                             0
# 202312312354_8                              0                             0
#
#                   adm1_sef intermittente sef_pre
# cluster_id2
# 202301010000_101                               0
# 202301010000_102                               0
# 202301010000_121                               0
# 202301010000_122                               0
# 202301010000_126                               0
# ...                                          ...
# 202312312352_14                                0
# 202312312352_6                                 0
# 202312312354_2                                 0
# 202312312354_6                                 0
# 202312312354_8                                 0
#
# [616261 rows x 1776 columns]

# %%
indices = np.arange(len(result_df_gt_2 ))
train_indices, test_indices = train_test_split(indices, test_size=0.3, random_state=42)
val_indices, test_indices = train_test_split(test_indices, test_size=0.5, random_state=42)

# %%
pd.DataFrame(train_indices).to_csv("train_indexes_link.csv", index=False)
pd.DataFrame(val_indices).to_csv("val_indexes_link.csv", index=False)
pd.DataFrame(test_indices).to_csv("test_indexes_link.csv", index=False)

# %%
train_indexes_df = pd.read_csv('train_indexes_link.csv')  
val_indexes_df = pd.read_csv('val_indexes_link.csv')
test_indexes_df = pd.read_csv('test_indexes_link.csv')

# %%
train_indexes = train_indexes_df.iloc[:, 0].values
val_indexes = val_indexes_df.iloc[:, 0].values
test_indexes = test_indexes_df.iloc[:, 0].values

# %%
result_df_gt_2 = result_df_gt_2.reset_index()

# %%
# Divide il DataFrame utilizzando gli indici
train_df = result_df_gt_2.loc[train_indexes]
val_df = result_df_gt_2.loc[val_indexes]
test_df = result_df_gt_2.loc[test_indexes]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Divide il DataFrame utilizzando gli indici
# ----> 2 train_df = result_df_gt_2.loc[train_indexes]
#       3 val_df = result_df_gt_2.loc[val_indexes]
#       4 test_df = result_df_gt_2.loc[test_indexes]
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# -> 1420     return self._getitem_iterable(key, axis=axis)
#    1422 # nested tuple slicing
#    1423 if is_nested_tuple(key, labels):
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\indexing.py:1361, in _LocIndexer._getitem_iterable(self, key, axis)
#    1359 # A collection of keys
#    1360 keyarr, indexer = self._get_listlike_indexer(key, axis)
# -> 1361 return self.obj._reindex_with_indexers(
#    1362     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1363 )
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\generic.py:5686, in NDFrame._reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    5683     indexer = ensure_platform_int(indexer)
#    5685 # TODO: speed up on homogeneous DataFrame objects (see _reindex_multi)
# -> 5686 new_data = new_data.reindex_indexer(
#    5687     index,
#    5688     indexer,
#    5689     axis=baxis,
#    5690     fill_value=fill_value,
#    5691     allow_dups=allow_dups,
#    5692     copy=copy,
#    5693 )
#    5694 # If we've made a copy once, no need to make another one
#    5695 copy = False
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\internals\managers.py:688, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File c:\VirtualEnvironment\envs\TIM_thesis\Lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 5.71 GiB for an array with shape (1776, 431382) and data type int64

# %%
train_df.to_parquet('train_df_link.parquet')
val_df.to_parquet('val_df_link.parquet')
test_df.to_parquet('test_df_link.parquet')

# %%
train_df = pd.read_parquet('train_df_link.parquet')
val_df = pd.read_parquet('val_df_link.parquet')
test_df = pd.read_parquet('test_df_link.parquet')

# %%
train_df = train_df.reset_index(drop=True).set_index('cluster_id2')
val_df = val_df.reset_index(drop=True).set_index('cluster_id2')
test_df = test_df.reset_index(drop=True).set_index('cluster_id2')

# %%
train_df.to_parquet('train_df_link.parquet')
val_df.to_parquet('val_df_link.parquet')
test_df.to_parquet('test_df_link.parquet')
