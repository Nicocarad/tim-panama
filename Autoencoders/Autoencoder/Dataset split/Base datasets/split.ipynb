# 202312210200_6                            0                           0
# 202312210208_7                            0                           0
#
#                  ptn2_signal degraded_None  rxm5_loss of signal los_gb100  \
# cluster_id2
# 202301090504_2                           0                              0
# 202301090504_3                           0                              0
# 202301090506_13                          0                              0
# 202301090506_4                           0                              0
# 202301090506_5                           0                              0
# ...                                    ...                            ...
# 202312200220_8                           0                              0
# 202312200222_2                           0                              0
# 202312200604_3                           0                              0
# 202312210200_6                           0                              0
# 202312210208_7                           0                              0
#
#                  adm1_loss of signal los_482  oadm1_apparato isolato_None  \
# cluster_id2
# 202301090504_2                             0                            0
# 202301090504_3                             0                            0
# 202301090506_13                            0                            0
# 202301090506_4                             0                            0
# 202301090506_5                             0                            0
# ...                                      ...                          ...
# 202312200220_8                             0                            0
# 202312200222_2                             0                            0
# 202312200604_3                             0                            0
# 202312210200_6                             0                            0
# 202312210208_7                             0                            0
#
#                  rmx5_loss of signal los_None  adm1_sef intermittente sef_pre
# cluster_id2
# 202301090504_2                              0                               0
# 202301090504_3                              0                               0
# 202301090506_13                             0                               0
# 202301090506_4                              0                               0
# 202301090506_5                              0                               0
# ...                                       ...                             ...
# 202312200220_8                              0                               0
# 202312200222_2                              0                               0
# 202312200604_3                              0                               0
# 202312210200_6                              0                               0
# 202312210208_7                              0                               0
#
# [3681 rows x 1755 columns]

# %%
indices = np.arange(len(bitmap))
train_indices, test_indices = train_test_split(indices, test_size=0.3, random_state=42)
val_indices, test_indices = train_test_split(test_indices, test_size=0.5, random_state=42)

# %%
pd.DataFrame(train_indices).to_csv("train_indexes_link.csv", index=False)
pd.DataFrame(val_indices).to_csv("val_indexes_link.csv", index=False)
pd.DataFrame(test_indices).to_csv("test_indexes_link.csv", index=False)

# %%
train_indexes_df = pd.read_csv('train_indexes_lp.csv')  
val_indexes_df = pd.read_csv('val_indexes_lp.csv')
test_indexes_df = pd.read_csv('test_indexes_lp.csv')

# %%
train_indexes = train_indexes_df.iloc[:, 0].values
val_indexes = val_indexes_df.iloc[:, 0].values
test_indexes = test_indexes_df.iloc[:, 0].values

# %%
result_df_gt_2 = pd.read_parquet('result_df_gt_2_lavoriprogrammati_1755.parquet')
result_df_gt_2 = result_df_gt_2.reset_index()

# %%
# Divide il DataFrame utilizzando gli indici
train_df = result_df_gt_2.loc[train_indexes]
val_df = result_df_gt_2.loc[val_indexes]
test_df = result_df_gt_2.loc[test_indexes]

# %%
train_df.to_parquet('train_df_link_lp.parquet')
val_df.to_parquet('val_df_link_lp.parquet')
test_df.to_parquet('test_df_link_lp.parquet')

# %%
train_df = pd.read_parquet('train_df_link_lp.parquet')
val_df = pd.read_parquet('val_df_link_lp.parquet')
test_df = pd.read_parquet('test_df_link_lp.parquet')

# %%
train_df = train_df.reset_index(drop=True).set_index('cluster_id2')
val_df = val_df.reset_index(drop=True).set_index('cluster_id2')
test_df = test_df.reset_index(drop=True).set_index('cluster_id2')

# %%
train_df.to_parquet('train_df_link_lp.parquet')
val_df.to_parquet('val_df_link_lp.parquet')
test_df.to_parquet('test_df_link_lp.parquet')
