# %%
import pandas as pd

# %%
clusters_bitmap = pd.read_parquet("real-time clusters/clusters_bitmap.parquet")

# %%
clusters_bitmap
# Out:
#                                  alimentazione  allarme alimentazione  \
# cluster_id      cluster_id2
# 202301150826_14 202301150826_9               0                      0
# 202307090754_11 202307090754_12              0                      0
# 202305050002_4  202305050002_3               0                      0
# 202306180732_8  202306180732_1               0                      0
# 202312221336_32 202312221336_14              0                      0
# ...                                        ...                    ...
# 202307311536_10 202307311534_14              0                      0
# 202308250106_17 202308250052_26              0                      0
# 202308161428_48 202308161428_27              0                      0
# 202307280032_35 202307280028_5               0                      0
# 202312241532_30 202312241532_11              0                      0
#
#                                  allarme interno  allarme protezione  \
# ...
