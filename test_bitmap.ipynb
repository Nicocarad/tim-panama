# %%
import pandas as pd

# %%
clusters_bitmap = pd.read_parquet("real-time clusters/result_df_gt_2.parquet")

# %%
clusters_bitmap
# Out:
#                   apparato isolato  loss of signal los  None  signal degraded  \
# cluster_id2
# 202301010000_100                 1                   0     0                0
# 202301010000_102                 1                   0     0                0
# 202301010000_103                 1                   0     0                0
# 202301010000_122                 1                   0     0                0
# 202301010000_123                 1                   0     0                0
# ...                            ...                 ...   ...              ...
# 202312312354_1                   0                   0     1                0
# 202312312354_3                   1                   0     0                0
# 202312312354_5                   0                   0     1                0
# 202312312354_7                   0                   0     1                0
# 202312312358_6                   0                   0     0                1
#
# ...

# %%
rows_with_multiple_ones = clusters_bitmap[clusters_bitmap.sum(axis=1) > 8]

# %%
rows_with_multiple_ones
# Out:
#                  apparato isolato  loss of signal los  None  signal degraded  \
# cluster_id2
# 202301010038_24                 1                   1     0                1
# 202301010832_10                 1                   1     1                1
# 202301020858_4                  1                   1     1                1
# 202301021256_2                  1                   0     1                1
# 202301021356_8                  1                   0     1                1
# ...                           ...                 ...   ...              ...
# 202312301926_11                 1                   1     1                1
# 202312310720_8                  1                   1     1                0
# 202312311106_11                 0                   1     0                0
# 202312312014_7                  1                   1     1                1
# 202312312206_8                  1                   1     0                1
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
from comet_ml import Experiment

# Creazione di un DataFrame di esempio (sostituisci questo con il tuo DataFrame effettivo)
data = {
    'slogan1': [1, 0, 1],
    'slogan2': [0, 1, 0],
    'slogan3': [1, 1, 0]
}
df = pd.DataFrame(data)
# Impostazione dell'indice del DataFrame
df.index = ['cluster1', 'cluster2', 'cluster3']

# Calcolo del numero di occorrenze di ciascuno slogan nel DataFrame
occurrences = df.sum(axis=0)

# Plotting
plt.bar(occurrences.index, occurrences.values)
plt.xlabel('Slogan')
plt.ylabel('Occorrenze')
plt.title('Occorrenze di Slogan nel Dataset')

# Salvataggio dell'immagine
plt.savefig("occurrences_plot.png")

# Invio dell'immagine a Comet ML
experiment = Experiment(api_key="knoxznRgLLK2INEJ9GIbmR7ww", project_name="your-project-name")
experiment.log_image(image_data="occurrences_plot.png")

plt.show()
# Out:
# COMET WARNING: To get all data logged automatically, import comet_ml before the following modules: torch.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     name                  : representative_compass_7297
# COMET INFO:     url                   : https://www.comet.com/nicocarad/your-project-name/a9953df1b1734b82a32344eca9b3fd5c
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (5.93 KB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO:
# ...
